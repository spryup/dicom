# %%
import os
import pydicom
import matplotlib.pyplot as plt

path="DICOM/IM_0001"

# %%
ds = pydicom.dcmread(path)

# %%
ds
# Out:
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'OBSTETRICAL']
# (0008, 0012) Instance Creation Date              DA: '20190527'
# (0008, 0013) Instance Creation Time              TM: '144846'
# (0008, 0016) SOP Class UID                       UI: Ultrasound Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113663.1500.1.378980256.3.1.20190527.144846.225
# (0008, 0020) Study Date                          DA: '20190527'
# (0008, 0021) Series Date                         DA: '20190527'
# (0008, 0023) Content Date                        DA: '20190527'
# (0008, 002a) Acquisition DateTime                DT: '20190527144845'
# (0008, 0030) Study Time                          TM: '144710'
# (0008, 0031) Series Time                         TM: '144710'
# (0008, 0033) Content Time                        TM: '144846'
# (0008, 0050) Accession Number                    SH: u''
# (0008, 0060) Modality                            CS: 'US'
# (0008, 0068) Presentation Intent Type            CS: 'FOR PRESENTATION'
# (0008, 0070) Manufacturer                        LO: u'Philips Medical Systems'
# (0008, 0080) Institution Name                    LO: u'BEST ULTRASOUND AND ECHO CENTRE'
# (0008, 0090) Referring Physician's Name          PN: u''
# (0008, 1010) Station Name                        SH: u''
# (0008, 1030) Study Description                   LO: u''
# (0008, 1048) Physician(s) of Record              PN: u''
# (0008, 1070) Operators' Name                     PN: u''
# (0008, 1090) Manufacturer's Model Name           LO: u'Affiniti 50G'
# (0008, 1111)  Referenced Performed Procedure Step Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113663.1500.1.378980256.5.1.20190527.144710.180
#    ---------
# (0008, 2111) Derivation Description              ST: u'0'
# (0010, 0010) Patient's Name                      PN: u'RINKI,475/5^^^^'
# (0010, 0020) Patient ID                          LO: u'DR.VALYA'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0010, 4000) Patient Comments                    LT: u''
# (0018, 1000) Device Serial Number                LO: u'378980256'
# (0018, 1020) Software Version(s)                 LO: u'Affiniti 50G_4.0.0.462'
# (0018, 1030) Protocol Name                       LO: u'Free Form'
# (0018, 1088) Heart Rate                          IS: "0"
# (0018, 5010) Transducer Data                     LO: ['C6_2', '53883', '']
# (0018, 5020) Processing Function                 LO: u'OB_GENERAL'
# (0018, 6011)  Sequence of Ultrasound Regions   1 item(s) ----
#    (0018, 6012) Region Spatial Format               US: 1
#    (0018, 6014) Region Data Type                    US: 1
#    (0018, 6016) Region Flags                        UL: 2
#    (0018, 6018) Region Location Min X0              UL: 14
#    (0018, 601a) Region Location Min Y0              UL: 38
#    (0018, 601c) Region Location Max X1              UL: 1010
#    (0018, 601e) Region Location Max Y1              UL: 758
#    (0018, 6024) Physical Units X Direction          US: 3
#    (0018, 6026) Physical Units Y Direction          US: 3
#    (0018, 602c) Physical Delta X                    FD: 0.02044065726738503
#    (0018, 602e) Physical Delta Y                    FD: 0.02044065726738503
#    ---------
# (0020, 000d) Study Instance UID                  UI: 1.2.840.113663.1500.1.378980256.1.1.20190527.144710.179
# (0020, 000e) Series Instance UID                 UI: 1.2.840.113663.1500.1.378980256.2.1.20190527.144710.180
# (0020, 0010) Study ID                            SH: u'20190527.144710'
# (0020, 0011) Series Number                       IS: "1"
# (0020, 0013) Instance Number                     IS: "1"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 768
# (0028, 0011) Columns                             US: 1024
# (0028, 0014) Ultrasound Color Data Present       US: 0
# (0028, 0030) Pixel Spacing                       DS: ['0.20440657267385', '0.20440657267385']
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0301) Burned In Annotation                CS: 'NO'
# (0028, 1050) Window Center                       DS: "127"
# (0028, 1051) Window Width                        DS: "254"
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0040, 0244) Performed Procedure Step Start Date DA: '20190527'
# (0040, 0245) Performed Procedure Step Start Time TM: '144710'
# (0040, 0253) Performed Procedure Step ID         SH: u'20190527.144710'
# (0040, 0254) Performed Procedure Step Descriptio LO: u''
# (0040, 0280) Comments on the Performed Procedure ST: u'None'
# (2001, 0010) Private Creator                     LO: u'Philips Imaging DD 001'
# (2001, 1063) [Examination Source]                CS: 'ELSEWHERE'
# (200d, 0020) Private Creator                     LO: u'Philips US Imaging DD 017'
# (200d, 0024) Private Creator                     LO: u'Philips US Imaging DD 021'
# (200d, 0026) Private Creator                     LO: u'Philips US Imaging DD 023'
# (200d, 0030) Private Creator                     LO: u'Philips US Imaging DD 033'
# (200d, 0039) Private Creator                     LO: u'Philips US Imaging DD 042'
# (200d, 003a) Private Creator                     LO: u'Philips US Imaging DD 043'
# (200d, 2005) [Unknown]                           LO: u'composite'
# (200d, 2407) Private tag data                    LO: u'CUSTOM_SELECTION_13'
# (200d, 2637) [Unknown]                           DA: '20190527'
# (200d, 2638) [Unknown]                           TM: '144710'
# (200d, 2645) Private tag data                    IS: "0"
# (200d, 2659) Private tag data                    IS: "0"
# (200d, 265a) Private tag data                    IS: "0"
# (200d, 265b) Private tag data                    IS: "0"
# (200d, 3014) [Unknown]                           IS: "1"
# (200d, 3022) Private tag data                    IS: "0"
# (200d, 3915) Private tag data                    IS: "0"
# (200d, 3916) Private tag data                    FD: 0.0
# (200d, 3a05) [Unknown]                           SH: u'ACCEPTED'
# (200d, 3a06) Private tag data                    IS: "0"
# (7fe0, 0010) Pixel Data                          OB: Array of 786432 bytes

# %%
# working with pydicom package: https://pydicom.github.io/pydicom/stable/auto_examples/index.html

#ds.PatientName contains ID and name
#ds.ImageType contains certain tags

# working with the image data
#ds.PixelData contains the raw bytes
#ds.pixel_array provides more useful pixel data for uncompressed and compressed images

# %%
plt.imshow(ds.pixel_array, cmap=plt.cm.bone)

# %%
path="DICOM/IM_0001"
ds = pydicom.dcmread(path)

# %%
plt.imshow(ds.pixel_array, cmap=plt.cm.bone)

# %%
path="DICOM/IM_0002"
ds = pydicom.dcmread(path)

# %%
plt.imshow(ds.pixel_array, cmap=plt.cm.bone)

# %%
path="DICOM/IM_0003"
ds = pydicom.dcmread(path)

# %%
plt.imshow(ds.pixel_array, cmap=plt.cm.bone)

# %%
path="DICOM/IM_0004"
ds = pydicom.dcmread(path)

# %%
plt.imshow(ds.pixel_array, cmap=plt.cm.bone)
